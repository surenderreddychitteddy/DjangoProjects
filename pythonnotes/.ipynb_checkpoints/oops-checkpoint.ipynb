# %%
print "hellcome to oopconcept"
def fun():
    print function#didnot excute bcz fun wont call
class emp:#cclass 
    a=20
    b=30
    print a
    print b
    print "end "
# Out:
# hellcome to oopconcept
# 20
# 30
# end

# %%
print "hellcome to oopconcept"
def fun():
    print function#didnot excute bcz fun wont call
class emp:#cclass 
    a=20
    b=30
    c=40
    print a
    print b
    print c

    print "end "
print "out side loop"
# Out:
# hellcome to oopconcept
# 20
# 30
# end
# out side loop

# %%
print "hellcome to oopconcept"
def fun():
    print function#didnot excute bcz fun wont call
class emp:#cclass 
    a=20
    b=30
    c=40
    print a
    print b
    print c# inside class variables 

    print "end "
print "out side loop"
print c#inside class variables did not call the out side the class
# Out:
# hellcome to oopconcept
# 20
# 30
# 40
# end
# out side loop
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1601fc23a750> in <module>()
#      12     print "end "
#      13 print "out side loop"
# ---> 14 print c
#
# NameError: name 'c' is not defined

# %%
print "hellcome to oopconcept"
f="hiii pavan"
def fun():
    print function#didnot excute bcz fun wont call
class emp:#cclass 
    a=20
    b=30
    c=40
    print a
    print b
    print c# inside class variables 
    print f# is declared out side call but we can user inside class also

    print "end "
print "out side loop"
#print c#inside class variables did not call the out side the class
# Out:
# hellcome to oopconcept
# 20
# 30
# 40
# hiii pavan
# end
# out side loop

# %%
print "hellcome to oopconcept"
def fun():
    print function#didnot excute bcz fun wont call
class emp:#cclass 
    a=20
    b=30
    c=40
    print a
    print b
    print c# inside class variables 
    def oop():
        print "wellcome to inside class method"
    oop()

    print "end "
print "out side loop"
#print c#inside class variables did not call the out side the class
# Out:
# hellcome to oopconcept
# 20
# 30
# 40
# wellcome to inside class method
# end
# out side loop

# %%
print "hellcome to oopconcept"
def fun():
    print function#didnot excute bcz fun wont call
class emp:#cclass 
    a=20
    b=30
    c=40
    print a
    print b
    print c# inside class variables 
    def oop():
        print "wellcome to inside class method"
oop()# this method declared only inside class to cll only inside call 

print "out side loop"
#print c#inside class variables did not call the out side the class
# Out:
# hellcome to oopconcept
# 20
# 30
# 40
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d98d49f15d11> in <module>()
#      11     def oop():
#      12         print "wellcome to inside class method"
# ---> 13 oop()
#      14
#      15 print "out side loop"
#
# NameError: name 'oop' is not defined

# %%
print "hellcome to oopconcept"
def fun():
    print "inside function"
    #didnot excute bcz fun wont call
class emp:#cclass 
    a=20
    b=30
    c=40
    print a
    print b
    print c# inside class variables 
    def oop():
        print "wellcome to inside class method"
        print"------"
    oop()

    print "end class "
print "######"
print "out side class"

fun()
#print c#inside class variables did not call the out side the class
# Out:
# hellcome to oopconcept
# 20
# 30
# 40
# wellcome to inside class method
# ------
# end class
# ######
# out side class
# inside function

# %%
print "wellcome oops concept"
def fun():
    print "out side function"
class student:
    print "inside class"
    name="pavan"
    age=23
    def fun1(a,b):
        print "inside class fun"
        print a
        print b
fun()
print "name out side class" ,student.name# to print inside class atributes call to the class name.atributes
# Out:
# wellcome oops concept
# inside class
# out side function
# name out side class pavan

# %%
class student:
    print "inside class"
    name="pavan"
    def fun1(a,b):
        print "inside class "
        print a
        print b
print "name out side class" ,student.name# to print inside class atributes call to the class name.atributes.
student.fun1(10,20)
# Out:
# inside class
# name out side class pavan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-5315bf151301> in <module>()
#       8         print b
#       9 print "name out side class" ,student.name# to print inside class atributes call to the class name.atributes.
# ---> 10 student.fun1(10,20)
#      11
#
# TypeError: unbound method fun1() must be called with student instance as first argument (got int instance instead)

# %%
class student:
    print "inside class"
    name="pavan"
    def fun1(a,b):
        print "inside class "
        print "a:",a
        print "b",b
print "name out side class" ,student.name# to print inside class atributes call to the class name.atributes.
st=student()
student.fun1(st,20)
# Out:
# inside class
# name out side class pavan
# inside class
# a: <__main__.student instance at 0x0000000006F82D08>
# b 20

# %%
class student:
    print "inside class"
    name="pavan"
    def fun1(a,b):
        print "inside class  print a,b"
        print "a:",a
        print "b",b
#print "name out side class" ,student.name# to print inside class atributes call to the class name.atributes.
st=student()
print " to call class instance or data object student name",st.name
student.fun1(st,20)
# Out:
# inside class
#  to call class instance or data object student name pavan
# inside class  print a,b
# a: <__main__.student instance at 0x0000000006925B48>
# b 20

# %%
class Student:
    def data(self,name,age):
        self.name=name
        self.age=age
    def getdata(self):
        return self.name,self.age
st=Student()
st.data("pavan",24)
st1=Student()
st1.data("su",25)
print st.getdata()
print st1.getdata()
# Out:
# ('pavan', 24)
# ('su', 25)

# %%
class Student:
    def data(self,name,age):
        self.name=name
        self.age=age
    def getdata(self):
        return self.name,self.age
st=Student()
st.data("pavan",24)
st1=Student()
st1.data()
print st.getdata()
print st1.getdata()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-903da0b57a34> in <module>()
#       8 st.data("pavan",24)
#       9 st1=Student()
# ---> 10 st1.data()
#      11 print st.getdata()
#      12 print st1.getdata()
#
# TypeError: data() takes exactly 3 arguments (1 given)

# %%
class Student:
    print "this is class"
    def __init__():# did not class this mwthod
        # st2:this is a  constructor,to intialize the data while creating an instance
       # step1: It will call __new__. what __new__ will do?. __new__ creates an instance and returns.

        print "hello init function"
    def getdata(self):
        return self.name,self.age
print
# Out:
# this is class

# %%
class Student:
    print "this is class"
    def __init__(self):# did not class this mwthod
        print "hello init function"
st=Student()
# Out:
# this is class
# hello init function

# %%
class Student:
    print "this is class"
    def __init__(self,name,age,add):# did not class this mwthod
        # self  is reference variable  which is always pointing to cuurent object
        print "hello init function"
        self.name=name
        self.age=age
        self.add=add
    def getdata(self):
        return self.name,self.age,self.add
st=Student("pavan",24,"uok")
st.getdata()
# Out:
# this is class
# hello init function
# ('pavan', 24, 'uok')

# %%
class Student:
    print "this is class"
    def __init__(self,name,age,add):# did not class this mwthod
        print "hello init function"
        self.name=name # inside constoutr useing self
        self.age=age
        self.add=add
        return None
    def getdata(self):
        return self.name,self.age,self.add
st=Student("pavan",24,"uok")
s11=Student("yashu",18,"hyd")# varied from object to obect 

print st.getdata()
print s11.getdata()
# Out:
# this is class
# hello init function
# hello init function
# ('pavan', 24, 'uok')
# ('yashu', 18, 'hyd')

# %%
class Student:
    print "this is class"
    def __init__(self,name,age,add):# did not class this mwthod
        print "hello init function"
        self.name=name
        self.age=age
        self.add=add
        return "hello"
    def getdata(self):
        return self.name,self.age,self.add
st=Student("pavan",24,"uok")
s11=Student("yashu",18,"hyd")

print st.getdata()
print s11.getdata()
# Out:
# this is class
# hello init function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-5749bf342aa9> in <module>()
#       9     def getdata(self):
#      10         return self.name,self.age,self.add
# ---> 11 st=Student("pavan",24,"uok")
#      12 s11=Student("yashu",18,"hyd")
#      13
#
# TypeError: __init__() should return None

# %%
class Animal:
    #static variableeg
    legs=4
    @classmethod# inside method body if we r jusing static variable then it go for classmethod
    # we can cll class name or object refrence
    def wall(cls,name):
        print '{}walks with {}legs'.format(name,cls.legs)
Animal.wall('dog')
# Out:
#  dogwalks with 4legs

# %%
import sys
class Customer:
    bank="pavan"
    def __init__(self,name,balance=0):
        self.name=name
        self.balance=balance
    def deposit(self,amt):
        self.balance=self.balance+amt
        print "after deposit balance",self.balance
    def withdra(self,amt):
        if amt>self.balance:
            print "insaficent found con not operation"
            sys.exit()
        self.balance=self.balance-amt
        print "after withdra balance",self.balance

print "wellcome to",Customer.bank
name=input("enter name")
c=Customer(name)
while True:
    
    print "d-deposit\nw-withdra\n e-exit"
    operation=input("enter ammount:")
    if operation=='d' or operation=='D':
        amt=float(input("enter ammount"))
        c.deposit(amt)

# %%
print "hh"
# Out:
# hh

# %%
class Student:
    print "this is class"
    def __init__(self,name,age,add):# did not class this mwthod
        print "hello init function"
        self.name=name
        self.age=age
        self.add=add
        return None
    def getdata(self):
        return self.name,self.age,self.add
    @staticmethod
    def static(a,b):#
        print a
        print b
    @classmethod
    def ma(cls):
        print "hello this is class"
Student.ma()


st=Student("pavan",24,"uok")
s11=Student("yashu",18,"hyd")
st.static(10,20)
Student.static(50,60)

print st.getdata()
print s11.getdata()
# Out:
# this is class
# hello this is class
# hello init function
# hello init function
# 10
# 20
# 50
# 60
# ('pavan', 24, 'uok')
# ('yashu', 18, 'hyd')

# %%
class Animal:
    # sattic vari

# %%
class Student:
    print "this is class"
    def __init__(self,name,age,add):# did not class this mwthod
        print "hello init function"
        self.name=name
        self.age=age
        self.add=add
        return None
    def getdata(self):
        return self.name,self.age,self.add
    @staticmethod
    def static(a,b):#
        print a
        print b
    @classmethod
    def ma(cls):
        print "hello this is class"


st=Student("pavan",24,"uok")
s11=Student("yashu",18,"hyd")
st.static(10,20)
Student.static(50,60)
Student.ma()
st.ma()

print st.getdata()
print s11.getdata()
# Out:
# this is class
# hello init function
# hello init function
# 10
# 20
# 50
# 60
# hello this is class
# hello this is class
# ('pavan', 24, 'uok')
# ('yashu', 18, 'hyd')

# %%
class Emp:
    company="KHYAATHI"
    def __init__(self,name,address,sal):
        self.name=name
        self.address=address
        self.sal=sal
        
    def inst(self):
        print "this is instance method"
        
    def get(self):
        return self.name, self.address, self.sal,self.company
    
#     @classmethod
#     def classmethod_dup(cls):
#         print "this is class method"
#     @classmethod
    def clm(cls):
        print "this is class method"
        
    @staticmethod
    def stam(a,b):
        print "this is static method"
        print "a=%s, b=%s"%(a,b)
        print "End static method"
p1=Emp("p1","ad1",23456)
print Emp.get(p1)
print p1.get()
#print Emp.get()
print "class with class method"

Emp.clm()
p1.clm()
print "class with static method"
Emp.stam(10,20)
p1.stam(100,200)
print Emp.company
#print Emp.name
print p1.company
# Out:
# ('p1', 'ad1', 23456, 'KHYAATHI')
# ('p1', 'ad1', 23456, 'KHYAATHI')
# class with class method
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-b1437c8f097d> in <module>()
#      30 print "class with class method"
#      31
# ---> 32 Emp.clm()
#      33 p1.clm()
#      34 print "class with static method"
#
# TypeError: unbound method clm() must be called with Emp instance as first argument (got nothing instead)

# %%
## inheritance
# accessing the parent calss methods and attributes in to child class using child class instance only
class c1:
    def op1(self):
        print "hello thiss c1 class"
class c2(c1):
    def op2(self):
        
        print "this is c2 class"
    
    def oparation(self):
        self.op2()
        self.op1()
c2=c2()
c2.oparation()
# Out:
# this is c2 class
# hello thiss c1 class

# %%
## inheritance
# accessing the parent calss methods and attributes in to child class using child class instance only
class c1:
    def op1(self):
        print "hello thiss c1 class"
class c2(c1):
    def op2(self):
        
        print "this is c2 class"
    def op1(self):
        print "this is c2 class op1 function"
    
    def oparation(self):
        self.op2()
        self.op1()
c2=c2()
c2.oparation()
# Out:
# this is c2 class
# this is c2 class op1 function

# %%
class person:#multilevel
    def student(self):
        print "this is student class"
class emp(person):
    def Employe(self):
        print "this is Employe"
class college(emp):
    def fun(self):
        print "this this college"
c=college()
c.fun()
c.Employe()
c.student()
# Out:
# this this college
# this is Employe
# this is student class

# %%
class father:#multiple
    def student(self):
        print "this is father class"
class mother(person):
    def Employe(self):
        print "this is mother"
class child(father,mother):
    def fun(self):
        print "this this child"
c=child()
c.fun()
c.Employe()
c.student()
# Out:
# this this child
# this is mother
# this is father class

# %%
# method overriding
class A:
    def nokia(self):
        print "nokia 625"
class B(A):
    def nokia(self):
        print "nokia 725"
b=B()
b.nokia()
# Out:
# nokia 725

# %%
#encapsulation
class car:
    def __init__(self):
        self.__updatesoftware()#__ is private 
    def disply(self):
        print "drive a car"
    def __updatesoftware(self):
        print "update"
c=car()
c.disply()
# Out:
# update
# drive a car

# %%
#encapsulation
class car:
#     def __init__(self):
#         self.__updatesoftware()#__ is private 
    def disply(self):
        print "drive a car"
    def __updatesoftware(self):
        print "update"
c=car()
c.disply()
# Out:
# drive a car

# %%
#encapsulation
class car:
    def __init__(self):
        self.__updatesoftware()#__ is private 
    def disply(self):
        print "drive a car"
    def __updatesoftware(self):
        print "update"
c=car()
c.disply()
c.__updatesofware()# cona not call out side call prive methid
# Out:
# update
# drive a car
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-a32d62006124> in <module>()
#       9 c=car()
#      10 c.disply()
# ---> 11 c.__updatesofware()
#
# AttributeError: car instance has no attribute '__updatesofware'

# %%
class emp:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def data(self):
        return self.a,self.b
e=emp(10,20)
e.data()
# Out:
# (10, 20)

# %%
class emp:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def data(self):
        return self.a,self.b
e=emp(10,20)
e1=emp(30,40)
e1.data()
e.data()
print e+e1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-21aa799d8156> in <module>()
#       9 e1.data()
#      10 e.data()
# ---> 11 print e+e1
#
# TypeError: unsupported operand type(s) for +: 'instance' and 'instance'

# %%
class emp:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def __add__(self1,self2):
        return (self1.a+self2.a),(self1.b+self2.b)
    
e=emp(10,20)
e1=emp(30,40)
print e+e1
# Out:
# (40, 60)

# %%
class emp:
    def __init__(self,a):
        self.a=a
    def __itr__(self):
        for elem in self.__dict__.items():
            return elem
    
e=emp("name")
for i in e:
    print i
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1b2f78733098> in <module>()
#       7
#       8 e=emp("name")
# ----> 9 for i in e:
#      10     print i
#
# TypeError: iteration over non-sequence

# %%
class Student(object):
    count=0
    def __new__(cls,name,age):
        if cls.count==0:
            obj=object.__new__(cls)
            cls.count=cls.count+1
            return obj
        else:
            raise Exception("can create only instance")
            
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def diply(self):
        return self.name,self.age
st=Student("pavan",24
st1=Student("pavan1",24)

st.diply()
st1.disply()
# Out:
#   File "<ipython-input-1-00a2712f8432>", line 17
#     st1=Student("pavan1",24)
#       ^
# SyntaxError: invalid syntax

# %%
class Student(object):
    count=0
    def __new__(cls,name,age):
        if cls.count==0:
            obj=object.__new__(cls)
            cls.count=cls.count+1
            return obj
        else:
            raise Exception("can create only instance")
            
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def diply(self):
        return self.name,self.age
st=Student("pavan",24)
st.diply()
# Out:
# ('pavan', 24)

# %%
class Student(object):
    count=0
    def __new__(cls,name,age):
        if cls.count==0:
            obj=object.__new__(cls)
            cls.count=cls.count+1
            return obj
        else:
            raise Exception("can create only instance")
            
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def diply(self):
        return self.name,self.age
st=Student("pavan",24)
st=Student("kk",23)
s2.disply()
st.diply()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-6231604acb2d> in <module>()
#      15         return self.name,self.age
#      16 st=Student("pavan",24)
# ---> 17 st=Student("kk",23)
#      18 s2.disply()
#      19 st.diply()
#
# <ipython-input-3-6231604acb2d> in __new__(cls, name, age)
#       7             return obj
#       8         else:
# ----> 9             raise Exception("can create only instance")
#      10
#      11     def __init__(self,name,age):
#
# Exception: can create only instance

# %%
class Student(object):
    count=0
    def __new__(cls,name,age):
        if cls.count==0:
            obj=object.__new__(cls)
            cls.count=cls.count+1
            return obj
        else:
            raise Exception("can create only instance")
            
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def diply(self):
        return self.name,self.age
st=Student("pavan",24)
st2=Student("pavan",24)

st.diply()
st2.diply()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-92-1e49f0eaa55d> in <module>()
#      14     def diply(self):
#      15         return self.name,self.age
# ---> 16 st=Student("pavan",24)
#      17 st2=Student("pavan",24)
#      18
#
# <ipython-input-92-1e49f0eaa55d> in __new__(cls, name, age)
#       7             return obj
#       8         else:
# ----> 9             raise Exception("can create only instance")
#      10
#      11     def __init__(self,name,age):
#
# Exception: can create only instance

# %%
num=151
b=str(151)
re=b[::-1]
print re
if b==re:
    print "palidram"
else:
    print "no"
# Out:
# 151
# palidram

# %% [markdown]
# # class a:
#     def hell()

# %%
class College:
    c_name="TKR" #static variable
    def __init__(self,s_name,s_roolno):
        self.s_name=s_name # inistace varible
        self.s_roolno=s_roolno
    def disply(self):
        return self.s_name,self.s_roolno,College.c_name
    @classmethod
    def name(cls): # static variable
        return cls.c_name
    @staticmethod
    def sum():
        print "hellow this is static"
        
c=College('pavan',446)
print c.disply()  
print College.name()
print College.sum()
print c.sum()
# Out:
# ('pavan', 446, 'TKR')
# TKR
# hellow this is static
# None
# hellow this is static
# None

# %%
class Emp:
    def __init__(self, name,empid, age=26, passport="", adhar=""):
        self.name=name
        self.empid=empid
        self.age=age
        self.passport=passport
        self.adhar=adhar
    def __add__(self1,self2):
        return ((self1.name,self2.name),(self1.age,self2.age))
    def __sub__(self1,self2):
        return ((self1.name,self2.name),(self1.age-self2.age))
    def __len__(self):
        return len(self.__dict__)
    def __iter__(self):
        for elem in self.__dict__.items():
            yield  elem
        
samba=Emp("sambasiva","228")
anil=Emp("Anil kumar","229",34,"23456werty")
print samba+anil
print samba-anil
print len(samba)
for i in samba:
    print i
# Out:
# (('sambasiva', 'Anil kumar'), (26, 34))
# (('sambasiva', 'Anil kumar'), -8)
# 5
# ('empid', '228')
# ('age', 26)
# ('name', 'sambasiva')
# ('passport', '')
# ('adhar', '')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e0fecc576e69> in <module>()
#      21 print samba-anil
#      22 print len(samba)
# ---> 23 for i in samba:
#      24     print i
#
# TypeError: __iter__ returned non-iterator of type 'NoneType'
